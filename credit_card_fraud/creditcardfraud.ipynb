# %% [markdown]
# Credit Card Fraud Detectation Project

# %%
#importing the libraries
import numpy as np
import pandas as pd #for dataframe
import matplotlib # for visualization
import seaborn as sns # for visualization
from sklearn.linear_model import LogisticRegression #forming model
from sklearn.metrics import accuracy_score #for testing accuracy
import warnings
warnings.filterwarnings('ignore')

# %%
# loading the training and testing data
traindata=pd.read_csv('fraudTrain.csv')
testdata=pd.read_csv('fraudTest.csv')

# %% [markdown]
# DATA PREPROCESSING

# %%
#tra is for training data
traindata
# Out:
#          Unnamed: 0 trans_date_trans_time               cc_num  \
# 0                 0   2019-01-01 00:00:18     2703186189652095
# 1                 1   2019-01-01 00:00:44         630423337322
# 2                 2   2019-01-01 00:00:51       38859492057661
# 3                 3   2019-01-01 00:01:16     3534093764340240
# 4                 4   2019-01-01 00:03:06      375534208663984
# ...             ...                   ...                  ...
# 1296670     1296670   2020-06-21 12:12:08       30263540414123
# 1296671     1296671   2020-06-21 12:12:19     6011149206456997
# 1296672     1296672   2020-06-21 12:12:32     3514865930894695
# 1296673     1296673   2020-06-21 12:13:36     2720012583106919
# 1296674     1296674   2020-06-21 12:13:37  4292902571056973207
#
#                                     merchant       category     amt  \
# 0                 fraud_Rippin, Kub and Mann       misc_net    4.97
# 1            fraud_Heller, Gutmann and Zieme    grocery_pos  107.23
# ...

# %%
#tst foe testing data
testdata
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 0                0   2020-06-21 12:14:25  2291163933867244
# 1                1   2020-06-21 12:14:33  3573030041201292
# 2                2   2020-06-21 12:14:53  3598215285024754
# 3                3   2020-06-21 12:15:15  3591919803438423
# 4                4   2020-06-21 12:15:17  3526826139003047
# ...            ...                   ...               ...
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care   29.84   Joanne
# ...

# %%
traindata.describe()
# Out:
#          Unnamed: 0        cc_num           amt           zip           lat  \
# count  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06
# mean   6.483370e+05  4.171920e+17  7.035104e+01  4.880067e+04  3.853762e+01
# std    3.743180e+05  1.308806e+18  1.603160e+02  2.689322e+04  5.075808e+00
# min    0.000000e+00  6.041621e+10  1.000000e+00  1.257000e+03  2.002710e+01
# 25%    3.241685e+05  1.800429e+14  9.650000e+00  2.623700e+04  3.462050e+01
# 50%    6.483370e+05  3.521417e+15  4.752000e+01  4.817400e+04  3.935430e+01
# 75%    9.725055e+05  4.642255e+15  8.314000e+01  7.204200e+04  4.194040e+01
# max    1.296674e+06  4.992346e+18  2.894890e+04  9.978300e+04  6.669330e+01
#
#                long      city_pop     unix_time     merch_lat    merch_long  \
# count  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06
# mean  -9.022634e+01  8.882444e+04  1.349244e+09  3.853734e+01 -9.022646e+01
# ...

# %%
#describe function gives stastacical analysis for the dataframe
testdata.describe()
# Out:
#           Unnamed: 0        cc_num            amt            zip  \
# count  555719.000000  5.557190e+05  555719.000000  555719.000000
# mean   277859.000000  4.178387e+17      69.392810   48842.628015
# std    160422.401459  1.309837e+18     156.745941   26855.283328
# min         0.000000  6.041621e+10       1.000000    1257.000000
# 25%    138929.500000  1.800429e+14       9.630000   26292.000000
# 50%    277859.000000  3.521417e+15      47.290000   48174.000000
# 75%    416788.500000  4.635331e+15      83.010000   72011.000000
# max    555718.000000  4.992346e+18   22768.110000   99921.000000
#
#                  lat           long      city_pop     unix_time  \
# count  555719.000000  555719.000000  5.557190e+05  5.557190e+05
# mean       38.543253     -90.231325  8.822189e+04  1.380679e+09
# std         5.061336      13.721780  3.003909e+05  5.201104e+06
# min        20.027100    -165.672300  2.300000e+01  1.371817e+09
# ...

# %%
#head shows first n tuples
traindata.head(5)
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %%
testdata.head(5)
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
#tail shows last n tuples
traindata.tail(5)
# Out:
#          Unnamed: 0 trans_date_trans_time               cc_num  \
# 1296670     1296670   2020-06-21 12:12:08       30263540414123
# 1296671     1296671   2020-06-21 12:12:19     6011149206456997
# 1296672     1296672   2020-06-21 12:12:32     3514865930894695
# 1296673     1296673   2020-06-21 12:13:36     2720012583106919
# 1296674     1296674   2020-06-21 12:13:37  4292902571056973207
#
#                                     merchant       category     amt  \
# 1296670                    fraud_Reichel Inc  entertainment   15.56
# 1296671             fraud_Abernathy and Sons    food_dining   51.70
# 1296672                 fraud_Stiedemann Ltd    food_dining  105.93
# 1296673  fraud_Reinger, Weissnat and Strosin    food_dining   74.90
# 1296674  fraud_Langosh, Wintheiser and Hyatt    food_dining    4.30
#
#                first       last gender                         street  ...  \
# 1296670         Erik  Patterson      M       162 Jessica Row Apt. 072  ...
# ...

# %%
testdata.tail(5)
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                      merchant        category     amt    first     last  \
# 555714  fraud_Reilly and Sons  health_fitness   43.77  Michael    Olson
# 555715   fraud_Hoppe-Parisian       kids_pets  111.84     Jose  Vasquez
# 555716        fraud_Rau-Robel       kids_pets   86.88      Ann   Lawson
# 555717  fraud_Breitenberg LLC          travel    7.99     Eric  Preston
# 555718      fraud_Dare-Marvin   entertainment   38.13   Samuel     Frey
#
#        gender                      street  ...      lat      long  city_pop  \
# 555714      M         558 Michael Estates  ...  40.4931  -91.8912       519
# ...

# %%
traindata.shape
#no of rows and columns
# Out:
# (1296675, 23)

# %%
testdata.shape
# Out:
# (555719, 23)

# %%
traindata.columns
#all the columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
testdata.columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
testdata.amt
# Out:
# 0           2.86
# 1          29.84
# 2          41.28
# 3          60.05
# 4           3.19
#            ...
# 555714     43.77
# 555715    111.84
# 555716     86.88
# 555717      7.99
# 555718     38.13
# Name: amt, Length: 555719, dtype: float64

# %%
testdata.is_fraud
# 0 for valid transaction
# 1 for fraud
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 555714    0
# 555715    0
# 555716    0
# 555717    0
# 555718    0
# Name: is_fraud, Length: 555719, dtype: int64

# %%
testdata.info()
#basic info about the columns like count of null value and datatype of columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555719 entries, 0 to 555718
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             555719 non-null  int64
#  1   trans_date_trans_time  555719 non-null  object
#  2   cc_num                 555719 non-null  int64
#  3   merchant               555719 non-null  object
#  4   category               555719 non-null  object
#  5   amt                    555719 non-null  float64
#  6   first                  555719 non-null  object
#  7   last                   555719 non-null  object
#  8   gender                 555719 non-null  object
#  9   street                 555719 non-null  object
#  10  city                   555719 non-null  object
#  11  state                  555719 non-null  object
#  12  zip                    555719 non-null  int64
#  13  lat                    555719 non-null  float64
# ...

# %%
traindata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296675 entries, 0 to 1296674
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   Unnamed: 0             1296675 non-null  int64
#  1   trans_date_trans_time  1296675 non-null  object
#  2   cc_num                 1296675 non-null  int64
#  3   merchant               1296675 non-null  object
#  4   category               1296675 non-null  object
#  5   amt                    1296675 non-null  float64
#  6   first                  1296675 non-null  object
#  7   last                   1296675 non-null  object
#  8   gender                 1296675 non-null  object
#  9   street                 1296675 non-null  object
#  10  city                   1296675 non-null  object
#  11  state                  1296675 non-null  object
#  12  zip                    1296675 non-null  int64
#  13  lat                    1296675 non-null  float64
# ...

# %%
traindata.isnull().sum()
#finding count of null value if any
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
testdata.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
traindata['is_fraud'].value_counts()
# Out:
# is_fraud
# 0    1289169
# 1       7506
# Name: count, dtype: int64

# %%
testdata['is_fraud'].value_counts()
# Out:
# is_fraud
# 0    553574
# 1      2145
# Name: count, dtype: int64

# %%
# renaming the lebel 
valid =traindata[tra.is_fraud == 0]
fraud= traindata[tra.is_fraud == 1]

# %%
print(valid.shape)
print(fraud.shape)
# Out:
# (1289169, 23)
# (7506, 23)

# %%
valid1 =testdata[tst.is_fraud == 0]
fraud1= testdata[tst.is_fraud == 1]

# %%
print(valid1.shape)
print(fraud1.shape)
# Out:
# (553574, 23)
# (2145, 23)

# %%
valid.amt.describe()
# Out:
# count    1.289169e+06
# mean     6.766711e+01
# std      1.540080e+02
# min      1.000000e+00
# 25%      9.610000e+00
# 50%      4.728000e+01
# 75%      8.254000e+01
# max      2.894890e+04
# Name: amt, dtype: float64

# %%
fraud.amt.describe()
# Out:
# count    7506.000000
# mean      531.320092
# std       390.560070
# min         1.060000
# 25%       245.662500
# 50%       396.505000
# 75%       900.875000
# max      1376.040000
# Name: amt, dtype: float64

# %%
valid1.amt.describe()
# Out:
# count    553574.000000
# mean         67.614408
# std         152.471931
# min           1.000000
# 25%           9.600000
# 50%          47.150000
# 75%          82.620000
# max       22768.110000
# Name: amt, dtype: float64

# %%
fraud1.amt.describe()
# Out:
# count    2145.000000
# mean      528.356494
# std       392.747594
# min         1.780000
# 25%       214.510000
# 50%       371.940000
# 75%       907.770000
# max      1320.920000
# Name: amt, dtype: float64

# %%
traindata.groupby('is_fraud')
traindata
# Out:
#          Unnamed: 0 trans_date_trans_time               cc_num  \
# 0                 0   2019-01-01 00:00:18     2703186189652095
# 1                 1   2019-01-01 00:00:44         630423337322
# 2                 2   2019-01-01 00:00:51       38859492057661
# 3                 3   2019-01-01 00:01:16     3534093764340240
# 4                 4   2019-01-01 00:03:06      375534208663984
# ...             ...                   ...                  ...
# 1296670     1296670   2020-06-21 12:12:08       30263540414123
# 1296671     1296671   2020-06-21 12:12:19     6011149206456997
# 1296672     1296672   2020-06-21 12:12:32     3514865930894695
# 1296673     1296673   2020-06-21 12:13:36     2720012583106919
# 1296674     1296674   2020-06-21 12:13:37  4292902571056973207
#
#                                     merchant       category     amt  \
# 0                 fraud_Rippin, Kub and Mann       misc_net    4.97
# 1            fraud_Heller, Gutmann and Zieme    grocery_pos  107.23
# ...

# %%
#eliminating the columns of object type as they dont have significant role
numerics = ['int64','int16','int32','float16','float32','float64']
tra1= traindata.select_dtypes(include=numerics)
#tra1.drop(columns=['lat','long','merch_lat','merch_long','Unnamed: 0','city_pop','unix_time'],inplace=True)
tra1.drop(columns=['Unnamed: 0',],inplace=True)
tra1.sample(30)
# Out:
#                       cc_num      amt    zip      lat      long  city_pop  \
# 675331         4900628639996    23.62  90650  33.9056 -118.0818    105549
# 1123363         571465035400    76.54  82514  43.0048 -108.8964      1645
# 572063       213156747557083     3.59  91206  34.1556 -118.2322    172817
# 754606      3542162746848552    86.57  56029  43.5089  -93.4824       744
# 676662   4736845434667908128    68.02  12910  44.8816  -73.6408      2148
# 131181       375767678113375    74.52  22853  38.6476  -78.7717      4367
# 1078484     4777065439639721  1118.84  19456  40.1334  -75.4536       737
# 782452   4797297220948468262    69.42  47451  38.8938  -86.5246      1228
# 755596       213195754007681     2.52  52576  41.2001  -92.1354       568
# 849567       378278619832195    86.63  97403  44.0385 -123.0614    191096
# 321495      4727244663135968    45.19  36507  30.8635  -87.7644     19090
# 290317      4836998673805450   206.48  49854  46.0062  -86.2555      6469
# ...

# %%
numerics = ['int64','int16','int32','float16','float32','float64']
tst2= testdata.select_dtypes(include=numerics)
#tst2.drop(columns=['lat','long','merch_lat','merch_long','Unnamed: 0','city_pop','unix_time'],inplace=True)
tst2.drop(columns=['Unnamed: 0'],inplace=True)
tst2
# Out:
#                   cc_num     amt    zip      lat      long  city_pop  \
# 0       2291163933867244    2.86  29209  33.9659  -80.9355    333497
# 1       3573030041201292   29.84  84002  40.3207 -110.4360       302
# 2       3598215285024754   41.28  11710  40.6729  -73.5365     34496
# 3       3591919803438423   60.05  32780  28.5697  -80.8191     54767
# 4       3526826139003047    3.19  49632  44.2529  -85.0170      1126
# ...                  ...     ...    ...      ...       ...       ...
# 555714    30560609640617   43.77  63453  40.4931  -91.8912       519
# 555715  3556613125071656  111.84  77566  29.0393  -95.4401     28739
# 555716  6011724471098086   86.88  99323  46.1966 -118.9017      3684
# 555717     4079773899158    7.99  83643  44.6255 -116.4493       129
# 555718  4170689372027579   38.13  73034  35.6665  -97.4798    116001
#
#          unix_time  merch_lat  merch_long  is_fraud
# 0       1371816865  33.986391  -81.200714         0
# ...

# %%
tra1.groupby('is_fraud').mean()
# Out:
#                 cc_num         amt           zip        lat       long  \
# is_fraud
# 0         4.172901e+17   67.667110  48805.107481  38.536888 -90.228142
# 1         4.003577e+17  531.320092  48038.714229  38.663609 -89.916041
#
#               city_pop     unix_time  merch_lat  merch_long
# is_fraud
# 0         88775.228137  1.349249e+09  38.536659  -90.228274
# 1         97276.763256  1.348389e+09  38.653901  -89.915808

# %%
#7506 fraud
valid_sample =valid.sample(n=7506)

# %%
#creating asn unifor data
ket =pd.concat([valid_sample,fraud],axis=0)

# %%
ket.head(5)
# Out:
#          Unnamed: 0 trans_date_trans_time               cc_num  \
# 327574       327574   2019-06-05 10:51:41     6597248210463122
# 194006       194006   2019-04-10 03:18:36  4128730454058057622
# 1056098     1056098   2020-03-14 17:16:06     3559723917628303
# 1084314     1084314   2020-03-26 15:15:32     2383461948823908
# 785061       785061   2019-12-01 06:13:59        4613314721966
#
#                               merchant        category     amt    first  \
# 327574   fraud_Lockman, West and Runte     grocery_pos  148.08     Kyle
# 194006       fraud_Schamberger-O'Keefe     grocery_pos  114.25  Monique
# 1056098         fraud_Torphy-Kertzmann  health_fitness   75.17  Matthew
# 1084314               fraud_Bednar Inc          travel    3.85  Patrick
# 785061            fraud_Kutch and Sons     grocery_pos   95.01    Jason
#
#             last gender                       street  ...      lat     long  \
# ...

# %%
ket.tail(5)
# Out:
#          Unnamed: 0 trans_date_trans_time            cc_num  \
# 1295399     1295399   2020-06-21 01:00:08  3524574586339330
# 1295491     1295491   2020-06-21 01:53:35  3524574586339330
# 1295532     1295532   2020-06-21 02:16:56  4005676619255478
# 1295666     1295666   2020-06-21 03:26:20  3560725013359375
# 1295733     1295733   2020-06-21 03:59:46  4005676619255478
#
#                                      merchant       category      amt  \
# 1295399                    fraud_Kassulke PLC   shopping_net   977.01
# 1295491                      fraud_Schumm PLC   shopping_net  1210.91
# 1295532  fraud_Tillman, Dickinson and Labadie  gas_transport    10.24
# 1295666                  fraud_Corwin-Collins  gas_transport    21.69
# 1295733                   fraud_Koss and Sons  gas_transport    10.20
#
#            first     last gender                        street  ...      lat  \
# 1295399   Ashley  Cabrera      F  94225 Smith Springs Apt. 617  ...  27.6330
# ...

# %%
ket.groupby('is_fraud')

# %%
numerics = ['int64','int16','int32','float16','float32','float64']
ket1= traindata.select_dtypes(include=numerics)
ket1
# Out:
#          Unnamed: 0               cc_num     amt    zip      lat      long  \
# 0                 0     2703186189652095    4.97  28654  36.0788  -81.1781
# 1                 1         630423337322  107.23  99160  48.8878 -118.2105
# 2                 2       38859492057661  220.11  83252  42.1808 -112.2620
# 3                 3     3534093764340240   45.00  59632  46.2306 -112.1138
# 4                 4      375534208663984   41.96  24433  38.4207  -79.4629
# ...             ...                  ...     ...    ...      ...       ...
# 1296670     1296670       30263540414123   15.56  84735  37.7175 -112.4777
# 1296671     1296671     6011149206456997   51.70  21790  39.2667  -77.5101
# 1296672     1296672     3514865930894695  105.93  88325  32.9396 -105.8189
# 1296673     1296673     2720012583106919   74.90  57756  43.3526 -102.5411
# 1296674     1296674  4292902571056973207    4.30  59871  45.8433 -113.8748
#
#          city_pop   unix_time  merch_lat  merch_long  is_fraud
# ...

# %%
ket1.groupby('is_fraud').mean()
# Out:
#              Unnamed: 0        cc_num         amt           zip        lat  \
# is_fraud
# 0         648473.169029  4.172901e+17   67.667110  48805.107481  38.536888
# 1         624949.724354  4.003577e+17  531.320092  48038.714229  38.663609
#
#                long      city_pop     unix_time  merch_lat  merch_long
# is_fraud
# 0        -90.228142  88775.228137  1.349249e+09  38.536659  -90.228274
# 1        -89.916041  97276.763256  1.348389e+09  38.653901  -89.915808

# %%
x = ket.drop(columns='is_fraud',axis=1)
y=ket['is_fraud']

# %%
print(x)
# Out:
#          Unnamed: 0 trans_date_trans_time               cc_num  \
# 327574       327574   2019-06-05 10:51:41     6597248210463122
# 194006       194006   2019-04-10 03:18:36  4128730454058057622
# 1056098     1056098   2020-03-14 17:16:06     3559723917628303
# 1084314     1084314   2020-03-26 15:15:32     2383461948823908
# 785061       785061   2019-12-01 06:13:59        4613314721966
# ...             ...                   ...                  ...
# 1295399     1295399   2020-06-21 01:00:08     3524574586339330
# 1295491     1295491   2020-06-21 01:53:35     3524574586339330
# 1295532     1295532   2020-06-21 02:16:56     4005676619255478
# 1295666     1295666   2020-06-21 03:26:20     3560725013359375
# 1295733     1295733   2020-06-21 03:59:46     4005676619255478
#
#                                      merchant        category      amt  \
# 327574          fraud_Lockman, West and Runte     grocery_pos   148.08
# ...

# %%
print(y)
# Out:
# 327574     0
# 194006     0
# 1056098    0
# 1084314    0
# 785061     0
#           ..
# 1295399    1
# 1295491    1
# 1295532    1
# 1295666    1
# 1295733    1
# Name: is_fraud, Length: 15012, dtype: int64

# %%
#testing variables
xtst=tst2.drop(columns='is_fraud',axis=1)
ytst=tst2['is_fraud']

# %%
#training variables
xtra=tra1.drop(columns='is_fraud',axis=1)
ytra=tra1['is_fraud']

# %%
xtst
# Out:
#                   cc_num     amt    zip      lat      long  city_pop  \
# 0       2291163933867244    2.86  29209  33.9659  -80.9355    333497
# 1       3573030041201292   29.84  84002  40.3207 -110.4360       302
# 2       3598215285024754   41.28  11710  40.6729  -73.5365     34496
# 3       3591919803438423   60.05  32780  28.5697  -80.8191     54767
# 4       3526826139003047    3.19  49632  44.2529  -85.0170      1126
# ...                  ...     ...    ...      ...       ...       ...
# 555714    30560609640617   43.77  63453  40.4931  -91.8912       519
# 555715  3556613125071656  111.84  77566  29.0393  -95.4401     28739
# 555716  6011724471098086   86.88  99323  46.1966 -118.9017      3684
# 555717     4079773899158    7.99  83643  44.6255 -116.4493       129
# 555718  4170689372027579   38.13  73034  35.6665  -97.4798    116001
#
#          unix_time  merch_lat  merch_long
# 0       1371816865  33.986391  -81.200714
# 1       1371816873  39.450498 -109.960431
# ...

# %%
#using LogisticRegressions
model=LogisticRegression()

# %%
model.fit(xtra,ytra)
# Out:
# LogisticRegression()

# %%
#checking accuracy 
x_p=model.predict(xtra)
tran_acc=accuracy_score(x_p,ytra)
tran_acc
# Out:
# 0.9942113482561166

# %%
#checking accuracy 
x_t_p=model.predict(xtst)
test_acc=accuracy_score(x_t_p,ytst)
test_acc
# Out:
# 0.9961401355721147

# %%
#using knn 
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.metrics import confusion_matrix , accuracy_score
#instantiate learning model(k=5)

c=KNeighborsClassifier(n_neighbors=1)

#fitting the model

c.fit(xtra,ytra)

#predicting the Test set Results
#0 for vaild
#1 for fraud

y_pred = c.predict(xtst)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
c.score(xtst,ytst) #accuracy score
# Out:
# 0.9907435232554582

# %%
#predicting the result 
#0 for vaild
#1 for fraud
model.predict([[359821528502475,41.28,11710,40.6729,-73.5365,34496,1371816893,40.495810	,-74.196111]])
# Out:
# array([0], dtype=int64)

# %%
model.predict(xtst)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
import pickle

# %%
#pickle.dump(c,open('mod2.pkl','wb'))
